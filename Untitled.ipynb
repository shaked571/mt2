# %%
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (15,10)

# %%
ner_res = pd.read_csv("ner_hd_100_b_16_l_r_0.003.csv")
pos_res = pd.read_csv("pos_hd_100_b_16_l_r_0.003.csv")

# %%
ner_res.plot(x="Step", y=["a", "b", "c", "d"])
# Out:
# <AxesSubplot:xlabel='Step'>

# %%
pos_res.plot(x="Step", y=["a", "b", "c", "d"])
# Out:
# <AxesSubplot:xlabel='Step'>

# %%
# Out:
# <AxesSubplot:xlabel='Step'>
