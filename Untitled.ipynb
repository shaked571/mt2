# %%
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (15,10)

# %%
part_2_blue = pd.read_csv("run-part_2_lr_0.002_batch_size_4_embed_size_256_hidden_dim_256_dropout_0.3_n_layers_2-tag-bleu_score_dev_epoch.csv")
part_2_loss = pd.read_csv("run-part_2_lr_0.002_batch_size_4_embed_size_256_hidden_dim_256_dropout_0.3_n_layers_2-tag-Loss_dev_epoch.csv")

# %%
part_2_blue.plot(x="Epoch", y=["part_2_bleu"],xticks=part_2_blue.Epoch)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
part_2_loss.plot(x="Epoch", y=["part_2_loss"], xticks=part_2_loss.Epoch)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
part_1_blue = pd.read_csv("run-part1_model-tag-bleu_score_dev_epoch.csv")
part_1_loss = pd.read_csv("run-part1_model-tag-Loss_dev_epoch.csv")

# %%
part_1_blue.plot(x="Epoch", y=["part_1_bleu"], xticks=part_1_blue.Epoch)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
part_1_loss.plot(x="Epoch", y=["part_1_loss"], xticks=part_1_blue.Epoch)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
part_1_blue
# Out:
#       Wall time  Epoch  part_1_bleu
# 0  1.623513e+09      1     8.587239
# 1  1.623513e+09      2    20.823458
# 2  1.623514e+09      3    37.021107
# 3  1.623514e+09      4    44.824852
# 4  1.623514e+09      5    48.144680
# 5  1.623514e+09      6    50.111240
# 6  1.623515e+09      7    58.008801
# 7  1.623515e+09      8    57.823391
# 8  1.623515e+09      9    57.634075
# 9  1.623515e+09     10    60.365379
